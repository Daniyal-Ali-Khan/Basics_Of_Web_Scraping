# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
webpage=requests.get('https://www.theforage.com/').text

# %%
soup = BeautifulSoup(webpage,'lxml') #'lxml' used to parser the html code

# %%
print(soup.prettify()) #prettify use to convert the code in real html format
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="Free Virtual Work Experience Programs from Top Companies - Forage." name="description"/>
#   <meta content="Forage" property="og:title"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="https://cdn-assets.theforage.com/favicon/ms-icon-144x144.png" name="msapplication-TileImage"/>
#   <meta content="9_KYWsgsLpEGMWMDSOB8gVw8qHcNgCDH0pBpmJxqCm0" name="google-site-verification"/>
#   <meta content="https://cdn-assets.theforage.com/images/social-sharing-preview.png" name="image" property="og:image"/>
#   <link href="https://cdn-assets.theforage.com/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="https://cdn-assets.theforage.com/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# ...

# %%
soup.find_all('h1')[0].text
# Out:
# 'Build confidence. Get the job.'

# %%
soup.find_all('h2')[0].text
# Out:
# 'Explore our free job simulations'

# %%
soup.find_all('h2')[1].text
# Out:
# 'Forage is the bridge between education and career success'

# %%
soup.find_all('h1')
# Out:
# [<h1 class="text-primary text-3xl md:text-4xl lg:text-5xl">Build confidence. Get the job.</h1>]

# %%
len(soup.find_all('h1'))
# Out:
# 1

# %%
len(soup.find_all('h2'))
# Out:
# 6

# %%
soup.find_all('h2')
# Out:
# [<h2 class="text-primary text-center text-4xl pb-4 md:mt-5">Explore our free job simulations</h2>,
#  <h2 class="text-primary text-4xl text-center">Forage is the bridge between education and career success</h2>,
#  <h2 class="text-primary text-center text-4xl pb-4 md:mt-5">Employers who are going beyond the resume</h2>,
#  <h2 class="text-primary text-center text-4xl pb-4 md:mt-5">Too good to be true? Hear from real students.</h2>,
#  <h2 class="text-center text-4xl pb-4 md:mt-5">Are you an employer interested in highly motivated candidates ready on Day One?</h2>,
#  <h2 class="text-primary text-4xl pb-4 md:mt-5">We want to build a world where candidates are considered equally on their merits.</h2>]

# %%
for i in soup.find_all('h2'):
    print(i.text)
# Out:
# Explore our free job simulations
# Forage is the bridge between education and career success
# Employers who are going beyond the resume
# Too good to be true? Hear from real students.
# Are you an employer interested in highly motivated candidates ready on Day One?
# We want to build a world where candidates are considered equally on their merits.

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())   #strip is used to remove the special characters like space or / etc.
# Out:
# Explore our free job simulations
# Forage is the bridge between education and career success
# Employers who are going beyond the resume
# Too good to be true? Hear from real students.
# Are you an employer interested in highly motivated candidates ready on Day One?
# We want to build a world where candidates are considered equally on their merits.

# %%
for i in soup.find_all('p'):
    print(i.text.strip())
# Out:
# Explore careers and prepare for the job with hundreds of free job simulations designed by the world's top employers.
# Our job simulations build real-life skills for real-life roles, offering a window into the company and a preview of their day-to-day. Job sims are 100% free, open access and self-paced.
# Register for Forage and tell us a little about yourself.
# Enroll in a job sim and complete tasks that replicate real work.
# Compare your work with model answers and earn a certificate.
# Access curated resources and a chance to connect with recruiters.
# 4x more likely
# to land a job after completing a job simulation
# Over 250 job simulations and 150+ employers
# across diverse industries and careers
# 3M+ students
# enrolled in Forage job simulations
# ...

# %%
soup.find_all('p',class_="text-lg text-center xl:text-xl")
# Out:
# [<p class="text-lg text-center xl:text-xl">Register for Forage and tell us a little about yourself.</p>,
#  <p class="text-lg text-center xl:text-xl">Enroll in a job sim and complete tasks that replicate real work.</p>,
#  <p class="text-lg text-center xl:text-xl">Compare your work with model answers and earn a certificate.</p>,
#  <p class="text-lg text-center xl:text-xl">Access curated resources and a chance to connect with recruiters.</p>]

# %%
len(soup.find_all('p',class_="text-lg text-center xl:text-xl"))
# Out:
# 4

# %%
soup.find_all(class_="frl_flex frl_justify-between frl_leading-[1rem]")
# Out:
# [<div class="frl_flex frl_justify-between frl_leading-[1rem]"><div class="frl_break-word frl_mr-2 frl_text-left">5 hours</div><div class="frl_break-word frl_ml-2 frl_text-right">Tech</div></div>,
#  <div class="frl_flex frl_justify-between frl_leading-[1rem]"><div class="frl_break-word frl_mr-2 frl_text-left">2-3 hours</div><div class="frl_break-word frl_ml-2 frl_text-right">Sales</div></div>,
#  <div class="frl_flex frl_justify-between frl_leading-[1rem]"><div class="frl_break-word frl_mr-2 frl_text-left">4-5 hours</div><div class="frl_break-word frl_ml-2 frl_text-right">Tech</div></div>,
#  <div class="frl_flex frl_justify-between frl_leading-[1rem]"><div class="frl_break-word frl_mr-2 frl_text-left">5-6 hours</div><div class="frl_break-word frl_ml-2 frl_text-right">Consulting</div></div>,
# ...

# %%
soup.find_all('a')
# Out:
# [<a class="mantine-Text-root mantine-Anchor-root mantine-1dsx3x9" href="/"><svg aria-label="Forage Logo" fill="none" height="2rem" viewbox="0 0 777 233" xmlns="http://www.w3.org/2000/svg"><path d="M353.821 114.672C352.875 116.494 351.22 118.654 348.86 121.153C342.919 126.956 336.103 129.858 328.405 129.858C324.98 129.858 321.696 129.25 318.553 128.044C318.304 127.949 318.055 127.848 317.808 127.744C316.913 127.372 316.029 126.953 315.157 126.481C313.737 125.712 312.347 124.813 310.989 123.781C310.792 123.654 310.577 123.495 310.353 123.321C310.163 123.172 309.96 123.005 309.748 122.821C309.484 122.592 309.208 122.345 308.912 122.061C308.709 121.867 308.5 121.661 308.283 121.441C307.631 120.783 306.913 120.012 306.129 119.127C301.335 113.118 298.939 106.435 298.939 99.0773C298.939 93.232 300.383 87.884 303.263 83.0333C303.741 82.2253 304.256 81.4307 304.815 80.6507C305.32 79.7027 306.512 78.2773 308.377 76.3827C308.505 76.2533 308.628 76.1267 308.763 75.992C310.823 74.1427 312.957 72.
# ...

# %%
len(soup.find_all('a'))
# Out:
# 45

# %%
soup.find_all('a')[1]
# Out:
# <a class="mantine-UnstyledButton-root mantine-Button-root bg-[#0072f4] text-white mantine-19wc3v1" data-button="true" href="/student-signup" type="button"><div class="mantine-1wpc1xj mantine-Button-inner"><span class="mantine-1ryt1ht mantine-Button-label"><div class="mantine-Text-root mantine-15jympw">Sign Up</div></span></div></a>

# %%
soup.find_all('a')[1].text
# Out:
# 'Sign Up'

# %%
soup.find_all(class_="mantine-Text-root mantine-15jympw")
# Out:
# [<div class="mantine-Text-root mantine-15jympw">Sign Up</div>]

# %%
soup.find_all(id_="w-node-_1679ab61-652e-f0d3-4ba3-427cf5294dfb-1601afd9")
# Out:
# []

# %%
company=soup.find_all('div',id_="w-node-_1679ab61-652e-f0d3-4ba3-427cf5294dfb-1601afd9")

# %%
len(company)
# Out:
# 0

# %%
name=[]
for i in company:
    name.append(i.find_all('h2').text.strip())

# %% [markdown]
# # Companies Website scraping

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
webpage=requests.get('https://www.business.com/articles/50-free-websites-to-list-your-business-2/').text

# %%
soup = BeautifulSoup(webpage,'lxml') #'lxml' used to parser the html code

# %%
print(soup.prettify()) #prettify html k code ko sahi formate main likhyga
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <title>
#    List Your Business on These 50 Free Websites
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="List Your Business on These 50 Free Websites" name="title"/>
#   <meta content="These 50 websites will allow you to list your business for free. Here's why you should use online directories and how you can do so effectively." name="description"/>
#   <meta content="max-image-preview:large, follow, index" name="robots"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="business.com" name="application-name"/>
#   <meta content="#003B5C" name="msapplication-TileColor"/>
#   <meta content="business.com" name="apple-mobile-web-app-title"/>
# ...

# %%
soup.find_all(class_="e13k7zy10 css-pdy1wd-GenericContainerStyles-ContentWrapper ezwpzks0")
# Out:
# [<div class="e13k7zy10 css-pdy1wd-GenericContainerStyles-ContentWrapper ezwpzks0"><section class="css-15f67eq-TableOfContentsDropDown eoxcsc3"><div class="css-ennwhm-HeadlineWrapper eoxcsc4"><h3 class="css-i94psq-Headline eoxcsc5">Table of Contents</h3><span><svg aria-labelledby="chevron-title" height="8px" role="img" style="transform:rotate(180deg)" version="1.1" viewbox="0 0 22.5 11.4" width="12px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px"><title id="chevron-title">Open row</title><polyline fill="none" points="21.4,10.4 11.2,1 1,10.4 " stroke="#000000" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" stroke-width="4"></polyline></svg></span></div></section><div class="e13k7zy11 css-1ky34x4-GenericContainerStyles-PageContent ezwpzks0"><div class="css-13he681-AuthorAndSocialWrapper eo58h660"><div class="css-1jv767p-ProfileWrapper e1ywp2h81"><div class="css-8tgboe-BDCProfileWrapper e1ywp2h82"
# ...

# %%
len(soup.find_all("a"))
# Out:
# 116

# %%
soup.find_all("a")[3].text
# Out:
# 'Finance'

# %%
for i in soup.find_all('a'):
    print(i.text)
# Out:
# Advertising Disclosure
# Advertise With Us53430510-B3C6-411A-B7C5-B11D2F2A9EC8@1x
# Starting a Business
# Finance
# Human Resources
# Marketing and Sales
# Technology
# Business Basics
# BDC Logo
# Starting a Business
# Finance
# Human Resources
# Marketing and Sales
# Technology
# Business Basics
# Home
# Marketing
# Marketing Strategy
# Max Freedman
# Share this on Facebook
# Share this on twitter
# Share this on LinkedIn
# company’s online presence
# website design
# amplify your business’s brand awareness
# protect your brand reputation
# Yelp
# Google
# Bing
# Facebook
# Better Business Bureau
# Angi
# MerchantCircle
# LinkedIn
# YP
# Whitepages
# Yellowbook
# Citysearch
# Yext
# Local.com
# Foursquare
# CitySlick.net
# USdirectory
# The Business Journals
# TomTom
# DiscoverOurTown.com
# EZlocal
# Manta
# Data Axle USA
# Infignos.com
# MyHuckleberry.com
# JustLocalBusiness
# Brownbook.net
# CitySquares
# HERE.com
# Judy’s Book
# Tripadvisor
# Thumbtack
# ...

# %%
company=soup.find_all('p',class_="css-xi606m")
company
# Out:
# [<p class="css-xi606m"><img alt="Yelp for Business" class="__3BkTm size-full wp-image-39057" decoding="async" height="375" loading="lazy" src="https://images.business.com/app/uploads/2016/02/22064946/yelp-for-business.jpg" width="468"/></p>,
#  <p class="css-xi606m"><img alt="Google Business profile" class="__3BkTm size-full wp-image-39058" decoding="async" height="635" loading="lazy" sizes="(max-width: 1430px) 100vw, 1430px" src="https://images.business.com/app/uploads/2016/02/22065107/google-business.png" srcset="https://images.business.com/app/uploads/2016/02/22065107/google-business.png 1430w, https://images.business.com/app/uploads/2016/02/22065107/google-business-1024x455.png 1024w" width="1430"/></p>,
#  <p class="css-xi606m"><img alt="Bing Places for Business" class="__3BkTm size-full wp-image-39059" decoding="async" height="335" loading="lazy" src="https://images.business.com/app/uploads/2016/02/22065242/bing-places-for-business.jpg" width="468"/></p>]

# %%
len(company)
# Out:
# 3

# %%
company[0].find_all('a',class_="MuiTypography-root MuiLink-root jss1 jss66 MuiLink-underlineNone jss58 MuiTypography-colorInherit")
# Out:
# []
